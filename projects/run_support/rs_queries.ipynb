# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
for df_name in ['glt', 'pit_careers', 'pit_seasons']:
    locals()[df_name] = pd.read_parquet(f'output/{df_name}.parquet')

# %%
pit_careers.query('game_id>=100').sort_values('rsi')
# Out:
#                             W     rs_wp       rsi  game_id  runs_scored_9  \
# starting_pitcher_id
# alcas001             0.463636  0.400878  0.747853      110       3.145455
# ruscg001             0.404145  0.434360  0.829092      193       3.834197
# kellb003             0.419048  0.417177  0.832893      105       3.809524
# urenj001             0.406015  0.430389  0.849962      133       3.676692
# franr001             0.424528  0.445888  0.854519      106       3.886792
# ...                       ...       ...       ...      ...            ...
# milot001             0.541096  0.555057  1.187964      146       5.047945
# friem001             0.694444  0.571107  1.188135      108       5.351852
# ramih002             0.495238  0.573558  1.203719      105       5.342857
# buehw001             0.660377  0.576130  1.229213      106       5.179245
# uriaj001             0.693069  0.603476  1.256374      101       5.237624
#
#                       re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id
# alcas001             4.236257  0.742508  0.370119
# ruscg001             4.633508  0.827493  0.415084
# kellb003             4.575118  0.832661  0.417118
# urenj001             4.355228  0.844202  0.426171
# franr001             4.521792  0.859569  0.428566
# ...                       ...       ...       ...
# milot001             4.260413  1.184849  0.578154
# friem001             4.478660  1.194967  0.578218
# ramih002             4.459465  1.198094  0.584023
# buehw001             4.226689  1.225367  0.593310
# uriaj001             4.174003  1.254820  0.602923
#
# [390 rows x 8 columns]

# %%
pit_careers.query('game_id>=100')[['rs_wp', 'runs_scored_9', 'rsi', 'rsi_wp']].corr()
# Out:
#                   rs_wp  runs_scored_9       rsi    rsi_wp
# rs_wp          1.000000       0.763671  0.964456  0.964632
# runs_scored_9  0.763671       1.000000  0.757889  0.757340
# rsi            0.964456       0.757889  1.000000  0.998441
# rsi_wp         0.964632       0.757340  0.998441  1.000000

# %%
px.scatter(pit_careers.query('game_id>=300').reset_index(), x='rsi_wp', y='rs_wp', hover_data=['starting_pitcher_id', 'rsi', 'runs_scored_9'], trendline='ols')

# %%
glt.query('starting_pitcher_id =="buehw001"').groupby('yr')[['runs_scored', 'runs_scored_9']].sum()
# Out:
#       runs_scored  runs_scored_9
# yr
# 2018          105            105
# 2019          175            173
# 2020           44             37
# 2021          180            168
# 2022           67             66

# %%
pit_seasons.query('game_id>=25').corr()
# Out:
#                       W     rs_wp       rsi   game_id  runs_scored_9  \
# W              1.000000  0.596455  0.572677  0.179712       0.498534
# rs_wp          0.596455  1.000000  0.957473  0.024982       0.849690
# rsi            0.572677  0.957473  1.000000  0.020280       0.876746
# game_id        0.179712  0.024982  0.020280  1.000000       0.048716
# runs_scored_9  0.498534  0.849690  0.876746  0.048716       1.000000
# re_pred       -0.020209 -0.000263 -0.014391  0.060685       0.460509
# rsi_agg2       0.572397  0.957308  0.998024  0.021237       0.880353
# rsi_wp         0.574613  0.959523  0.995123  0.026158       0.873375
#
#                 re_pred  rsi_agg2    rsi_wp
# W             -0.020209  0.572397  0.574613
# rs_wp         -0.000263  0.957308  0.959523
# rsi           -0.014391  0.998024  0.995123
# game_id        0.060685  0.021237  0.026158
# runs_scored_9  0.460509  0.880353  0.873375
# re_pred        1.000000 -0.010452 -0.012875
# rsi_agg2      -0.010452  1.000000  0.993290
# rsi_wp        -0.012875  0.993290  1.000000

# %%
pit_careers.query('game_id>=100').corr()
# Out:
#                       W     rs_wp       rsi   game_id  runs_scored_9  \
# W              1.000000  0.598321  0.602061  0.264743       0.439200
# rs_wp          0.598321  1.000000  0.964456  0.092249       0.763671
# rsi            0.602061  0.964456  1.000000  0.096327       0.757889
# game_id        0.264743  0.092249  0.096327  1.000000       0.040549
# runs_scored_9  0.439200  0.763671  0.757889  0.040549       1.000000
# re_pred       -0.081031 -0.040862 -0.090466 -0.056895       0.577298
# rsi_agg2       0.601197  0.964536  0.997229  0.090321       0.771244
# rsi_wp         0.599708  0.964632  0.998441  0.106916       0.757340
#
#                 re_pred  rsi_agg2    rsi_wp
# W             -0.081031  0.601197  0.599708
# rs_wp         -0.040862  0.964536  0.964632
# rsi           -0.090466  0.997229  0.998441
# game_id       -0.056895  0.090321  0.106916
# runs_scored_9  0.577298  0.771244  0.757340
# re_pred        1.000000 -0.072725 -0.090104
# rsi_agg2      -0.072725  1.000000  0.995896
# rsi_wp        -0.090104  0.995896  1.000000

# %%
pit_seasons.query('game_id>=25').sort_values('rs_wp')
# Out:
#                                  W     rs_wp       rsi  game_id  \
# starting_pitcher_id yr
# turns003            2019  0.233333  0.282665  0.525557       30
# mussm001            2000  0.470588  0.313655  0.603478       34
# kellb003            2019  0.321429  0.320193  0.603685       28
# blaiw001            1998  0.240000  0.320870  0.616678       25
# hendm001            2006  0.360000  0.330154  0.622332       25
# ...                            ...       ...       ...      ...
# paxtj001            2019  0.689655  0.673393  1.404809       29
# estes001            2000  0.666667  0.673885  1.496978       30
# saunj001            2009  0.645161  0.687042  1.391127       31
# abbop001            2001  0.814815  0.692002  1.518275       27
# hutcd001            2015  0.642857  0.718952  1.520207       28
#
#                           runs_scored_9   re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id yr
# turns003            2019       2.533333  4.819774  0.525612  0.235550
# mussm001            2000       3.147059  5.248084  0.599659  0.284096
# kellb003            2019       2.928571  4.887700  0.599172  0.284224
# blaiw001            1998       2.920000  4.665434  0.625880  0.292218
# hendm001            2006       2.840000  4.634892  0.612743  0.295684
# ...                                 ...       ...       ...       ...
# paxtj001            2019       6.827586  4.847870  1.408368  0.650678
# estes001            2000       7.300000  4.850675  1.504945  0.676626
# saunj001            2009       6.290323  4.523405  1.390617  0.646596
# abbop001            2001       7.037037  4.667764  1.507582  0.682257
# hutcd001            2015       6.607143  4.349285  1.519133  0.682761
#
# [2326 rows x 8 columns]

# %%
px.scatter(pit_seasons.query('game_id>=35').reset_index(), x='rsi_wp', y='rs_wp', hover_data=['starting_pitcher_id', 'yr', 'rsi'], trendline='ols')

# %%
print(pit_seasons.query('starting_pitcher_id == "degrj001"'))
# Out:
#                                  W     rs_wp       rsi  game_id  \
# starting_pitcher_id yr
# degrj001            2014  0.500000  0.509641  1.031136       22
#                     2015  0.666667  0.523509  1.097852       30
#                     2016  0.500000  0.441200  0.854123       24
#                     2017  0.548387  0.560313  1.159906       31
#                     2018  0.437500  0.430449  0.819350       32
#                     2019  0.437500  0.473747  0.931813       32
#                     2020  0.666667  0.579580  1.305972       12
#                     2021  0.733333  0.482324  0.869413       15
#                     2022  0.545455  0.435264  0.874856       11
#
#                           runs_scored_9   re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id yr
# degrj001            2014       3.727273  3.634760  1.025452  0.514024
#                     2015       4.300000  3.893669  1.104357  0.542607
#                     2016       3.458333  4.093188  0.844900  0.428358
#                     2017       5.064516  4.305734  1.176226  0.567451
#                     2018       3.437500  4.127653  0.832798  0.409843
#                     2019       4.156250  4.420350  0.940254  0.467735
#                     2020       5.916667  4.399831  1.344749  0.619756
#                     2021       3.600000  4.160472  0.865287  0.436327
#                     2022       3.454545  3.981591  0.867629  0.439138

# %%
pit_careers.query('starting_pitcher_id == "hernf002"')
# Out:
#                             W     rs_wp       rsi  game_id  runs_scored_9  \
# starting_pitcher_id
# hernf002             0.538278  0.468948  0.930216      418       3.930622
#
#                      re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id
# hernf002             4.23489  0.928152  0.466954

# %%
pit_seasons.query('starting_pitcher_id == "hernf002"')
# Out:
#                                  W     rs_wp       rsi  game_id  \
# starting_pitcher_id yr
# hernf002            2005  0.416667  0.317499  0.656275       12
#                     2006  0.451613  0.453546  0.900608       31
#                     2007  0.700000  0.552502  1.145086       30
#                     2008  0.483871  0.426107  0.801913       31
#                     2009  0.735294  0.522258  0.963304       34
#                     2010  0.500000  0.391027  0.722306       34
#                     2011  0.515152  0.450872  0.880407       33
#                     2012  0.484848  0.450914  0.855993       33
#                     2013  0.451613  0.462744  0.960223       31
#                     2014  0.647059  0.511982  1.106471       34
#                     2015  0.612903  0.504788  0.962736       31
#                     2016  0.600000  0.467020  1.014638       25
#                     2017  0.562500  0.589263  1.226675       16
#                     2018  0.392857  0.460285  0.860236       28
#                     2019  0.333333  0.410861  0.860097       15
#
#                           runs_scored_9   re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id yr
# hernf002            2005       2.833333  4.373164  0.647891  0.316316
#                     2006       4.290323  4.707597  0.911361  0.452252
#                     2007       5.200000  4.551098  1.142581  0.561666
#                     2008       3.516129  4.461763  0.788058  0.400356
#                     2009       4.235294  4.407401  0.960951  0.482902
#                     2010       3.000000  4.208979  0.712762  0.355417
#                     2011       3.545455  4.060809  0.873091  0.441990
#                     2012       3.424242  4.007111  0.854541  0.429338
#                     2013       3.741935  3.921617  0.954182  0.481439
#                     2014       4.147059  3.782095  1.096498  0.546156
#                     2015       3.935484  4.026000  0.977517  0.482633
#                     2016       4.240000  4.245156  0.998785  0.506648
#                     2017       5.437500  4.421197  1.229870  0.592397
#                     2018       3.642857  4.156143  0.876499  0.431556
#                     2019       4.066667  4.634495  0.877478  0.431484

# %%
len(pit_careers.query('game_id>=200 ')), len(pit_careers.query('game_id>=200 and rs_wp>.46895'))
# Out:
# (190, 178)

# %%
glt.query('starting_pitcher_id == "degrj001" and yr==2019')['re_pred'].mean()
# Out:
# 4.420349537633564

# %%
glt.query('team=="NYN" and yr==2019')['re_pred'].mean()
# Out:
# 4.478084177433939

# %%
glt.query('starting_pitcher_id == "degrj001" and yr==2018')['runs_allowed'].sum()
# Out:
# 104

# %%
(132-59)/32
# Out:
# 2.28125

# %%
(104-48)/32
# Out:
# 1.75

# %%
pit_careers.query('game_id>=300 ').sort_values('rs_wp')
# Out:
#                             W     rs_wp       rsi  game_id  runs_scored_9  \
# starting_pitcher_id
# cainm001             0.474320  0.465200  0.910427      331       3.788520
# hernf002             0.538278  0.468948  0.930216      418       3.930622
# burna001             0.497674  0.480699  0.941691      430       4.169767
# millk004             0.524138  0.481142  0.964984      435       4.510345
# haraa001             0.488189  0.481397  0.975053      381       4.230971
# ...                       ...       ...       ...      ...            ...
# lowed001             0.540761  0.533963  1.083103      368       4.853261
# lestj001             0.603104  0.536157  1.108668      451       4.949002
# kersc001             0.665829  0.540481  1.126201      398       4.540201
# porcr001             0.561254  0.548837  1.108670      351       5.042735
# waina001             0.633333  0.550339  1.154463      390       4.869231
#
#                       re_pred  rsi_agg2    rsi_wp
# starting_pitcher_id
# cainm001             4.178299  0.906713  0.457173
# hernf002             4.234890  0.928152  0.466954
# burna001             4.420413  0.943298  0.472542
# millk004             4.692880  0.961104  0.483699
# haraa001             4.362598  0.969828  0.488444
# ...                       ...       ...       ...
# lowed001             4.484994  1.082111  0.536457
# lestj001             4.464634  1.108490  0.547056
# kersc001             4.052557  1.120330  0.554160
# porcr001             4.533030  1.112442  0.547056
# waina001             4.216618  1.154772  0.565337
#
# [66 rows x 8 columns]
