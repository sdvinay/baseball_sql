# %%
import pandas as pd
import boxball_loader as bbl
import baseball_stats_utils as bsu

# %%
# Get the MVP vote totals from the Lahman database
mvp_votes = pd.read_parquet('../data/baseballdatabank/awards_share_players.parquet').query('award_id=="MVP"')
mvp_votes.sample(10)
# Out:
#      award_id  year_id lg_id  player_id  points_won  points_max  votes_first
# 2725      MVP     1956    NL  labincl01         1.0         336          0.0
# 5226      MVP     2003    NL  bondsba01       426.0         448         28.0
# 1818      MVP     1942    AL  hughste01        92.0         336          0.0
# 2686      MVP     1956    AL    foxne01        28.0         336          0.0
# 3280      MVP     1966    NL  brocklo01         2.0         280          0.0
# 1406      MVP     1934    NL  wanerpa01        50.0          80          NaN
# 2178      MVP     1947    NL  kurowwh01        45.0         336          0.0
# 3097      MVP     1963    NL  callijo01        11.0         280          0.0
# 3523      MVP     1970    NL  grangwa01         1.0         336          0.0
# 6839      MVP     2016    NL  hendrky01         2.0         420          0.0

# %%
# What years do we have voting for?
max_year = mvp_votes['year_id'].max()
max_year
# Out:
# 2016

# %%
# Generate a summary for each player (first yr on ballot, final yr, number of appearances)
vote_summary = mvp_votes.groupby('player_id').agg(first_yr = ('year_id', min), last_yr = ('year_id', max), appearances=('year_id', len))
vote_summary
# Out:
#            first_yr  last_yr  appearances
# player_id
# aaronha01      1955     1973           19
# abernte02      1967     1967            1
# abramca01      1954     1954            1
# abreubo01      1999     2009            7
# abreujo02      2014     2015            2
# ...             ...      ...          ...
# zimmehe01      1912     1913            2
# zimmery01      2009     2012            3
# ziskri01       1974     1977            3
# zitoba01       2001     2002            2
# zobribe01      2009     2012            3
#
# [1905 rows x 3 columns]

# %%
# Load the winners, and merge in the vote summary for each year's winner, and add player names
mvp_winners = pd.read_parquet('../data/baseballdatabank/awards_players.parquet').query('award_id=="Most Valuable Player" and year_id<=@max_year')
mvp_winners = pd.merge(left=mvp_winners, right=vote_summary, on='player_id')
mvp_winners['name'] = bsu.get_player_names_col(mvp_winners['player_id'], 'player_id')
mvp_winners
# Out:
#      player_id              award_id  year_id lg_id   tie notes  first_yr  \
# 0     cobbty01  Most Valuable Player     1911    AL  None  None      1911
# 1    schulfr01  Most Valuable Player     1911    NL  None  None      1911
# 2    speaktr01  Most Valuable Player     1912    AL  None  None      1911
# 3    doylela01  Most Valuable Player     1912    NL  None  None      1911
# 4    johnswa01  Most Valuable Player     1913    AL  None  None      1911
# ..         ...                   ...      ...   ...   ...   ...       ...
# 189  troutmi01  Most Valuable Player     2016    AL  None  None      2012
# 190  kershcl01  Most Valuable Player     2014    NL  None  None      2011
# 191  donaljo02  Most Valuable Player     2015    AL  None  None      2013
# 192  harpebr03  Most Valuable Player     2015    NL  None  None      2012
# 193  bryankr01  Most Valuable Player     2016    NL  None  None      2015
#
#      last_yr  appearances             name
# 0       1914            4          Ty Cobb
# 1       1911            1    Frank Schulte
# 2       1914            4     Tris Speaker
# 3       1913            3      Larry Doyle
# 4       1924            6   Walter Johnson
# ..       ...          ...              ...
# 189     2016            5       Mike Trout
# 190     2015            5  Clayton Kershaw
# 191     2016            4   Josh Donaldson
# 192     2015            2     Bryce Harper
# 193     2016            2      Kris Bryant
#
# [194 rows x 10 columns]

# %%
# Winners who were never on a ballot in another year
mvp_winners.query('appearances==1')
# Out:
#      player_id              award_id  year_id lg_id   tie notes  first_yr  \
# 1    schulfr01  Most Valuable Player     1911    NL  None  None      1911
# 9    sislege01  Most Valuable Player     1922    AL  None  None      1922
# 16   ofarrbo01  Most Valuable Player     1926    NL  None  None      1926
# 60   konstji01  Most Valuable Player     1950    NL  None  None      1950
# 131  hernawi01  Most Valuable Player     1984    AL  None  None      1984
# 134  mcgeewi01  Most Valuable Player     1985    NL  None  None      1985
# 158  caminke01  Most Valuable Player     1996    NL  None  None      1996
#
#      last_yr  appearances              name
# 1       1911            1     Frank Schulte
# 9       1922            1     George Sisler
# 16      1926            1     Bob O'Farrell
# 60      1950            1     Jim Konstanty
# 131     1984            1  Willie Hernandez
# 134     1985            1      Willie McGee
# 158     1996            1      Ken Caminiti

# %%
# Winners who had never been on a ballot before their win
firsts = mvp_winners.query('year_id==first_yr')
firsts
# Out:
#      player_id              award_id  year_id lg_id   tie notes  first_yr  \
# 0     cobbty01  Most Valuable Player     1911    AL  None  None      1911
# 1    schulfr01  Most Valuable Player     1911    NL  None  None      1911
# 9    sislege01  Most Valuable Player     1922    AL  None  None      1922
# 10    ruthba01  Most Valuable Player     1923    AL  None  None      1923
# 11   vanceda01  Most Valuable Player     1924    NL  None  None      1924
# 16   ofarrbo01  Most Valuable Player     1926    NL  None  None      1926
# 29   hubbeca01  Most Valuable Player     1933    NL  None  None      1933
# 41   waltebu01  Most Valuable Player     1939    NL  None  None      1939
# 50   newhoha01  Most Valuable Player     1944    AL  None  None      1944
# 60   konstji01  Most Valuable Player     1950    NL  None  None      1950
# 70    mayswi01  Most Valuable Player     1954    NL  None  None      1954
# 81   marisro01  Most Valuable Player     1960    AL  None  None      1960
# 102   bluevi01  Most Valuable Player     1971    AL  None  None      1971
# 107  burroje01  Most Valuable Player     1974    AL  None  None      1974
# 108  garvest01  Most Valuable Player     1974    NL  None  None      1974
# 109   lynnfr01  Most Valuable Player     1975    AL  None  None      1975
# 118  hernake01  Most Valuable Player     1979    NL     Y  None      1979
# 131  hernawi01  Most Valuable Player     1984    AL  None  None      1984
# 132  sandbry01  Most Valuable Player     1984    NL  None  None      1984
# 134  mcgeewi01  Most Valuable Player     1985    NL  None  None      1985
# 135  clemero02  Most Valuable Player     1986    AL  None  None      1986
# 140  mitchke01  Most Valuable Player     1989    NL  None  None      1989
# 142  bondsba01  Most Valuable Player     1990    NL  None  None      1990
# 158  caminke01  Most Valuable Player     1996    NL  None  None      1996
# 166  suzukic01  Most Valuable Player     2001    AL  None  None      2001
# 175  morneju01  Most Valuable Player     2006    AL  None  None      2006
# 176  howarry01  Most Valuable Player     2006    NL  None  None      2006
# 178  pedrodu01  Most Valuable Player     2008    AL  None  None      2008
#
#      last_yr  appearances              name
# 0       1914            4           Ty Cobb
# 1       1911            1     Frank Schulte
# 9       1922            1     George Sisler
# 10      1932            3         Babe Ruth
# 11      1928            3       Dazzy Vance
# 16      1926            1     Bob O'Farrell
# 29      1941            6      Carl Hubbell
# 41      1944            5     Bucky Walters
# 50      1948            4     Hal Newhouser
# 60      1950            1     Jim Konstanty
# 70      1971           15       Willie Mays
# 81      1964            3       Roger Maris
# 102     1978            4         Vida Blue
# 107     1978            3    Jeff Burroughs
# 108     1984            9      Steve Garvey
# 109     1980            4         Fred Lynn
# 118     1986            8   Keith Hernandez
# 131     1984            1  Willie Hernandez
# 132     1992            6     Ryne Sandberg
# 134     1985            1      Willie McGee
# 135     2005           10     Roger Clemens
# 140     1994            3    Kevin Mitchell
# 142     2004           15       Barry Bonds
# 158     1996            1      Ken Caminiti
# 166     2010            9     Ichiro Suzuki
# 175     2014            4    Justin Morneau
# 176     2011            6       Ryan Howard
# 178     2013            3    Dustin Pedroia

# %%
# Pretty-print the modern ones
firsts[['name', 'year_id', 'lg_id']].query('year_id>1947')
# Out:
#                  name  year_id lg_id
# 60      Jim Konstanty     1950    NL
# 70        Willie Mays     1954    NL
# 81        Roger Maris     1960    AL
# 102         Vida Blue     1971    AL
# 107    Jeff Burroughs     1974    AL
# 108      Steve Garvey     1974    NL
# 109         Fred Lynn     1975    AL
# 118   Keith Hernandez     1979    NL
# 131  Willie Hernandez     1984    AL
# 132     Ryne Sandberg     1984    NL
# 134      Willie McGee     1985    NL
# 135     Roger Clemens     1986    AL
# 140    Kevin Mitchell     1989    NL
# 142       Barry Bonds     1990    NL
# 158      Ken Caminiti     1996    NL
# 166     Ichiro Suzuki     2001    AL
# 175    Justin Morneau     2006    AL
# 176       Ryan Howard     2006    NL
# 178    Dustin Pedroia     2008    AL
