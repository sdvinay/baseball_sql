# %%
import pandas as pd

# %%
sched = pd.read_parquet('../data/retrosheet/schedule.parquet')
sched.columns
# Out:
# Index(['date', 'double_header', 'day_of_week', 'visiting_team',
#        'visiting_team_league', 'visiting_team_game_number', 'home_team',
#        'home_team_league', 'home_team_game_number', 'day_night',
#        'postponement_indicator', 'makeup_dates'],
#       dtype='object')

# %%
sched['yr'] = sched['date'].dt.year

sched.sample(10)
# Out:
#              date  double_header day_of_week visiting_team  \
# 70528  1929-04-20              0         Sat           BOS
# 102422 2019-09-21              0         Sat           ARI
# 188422 1907-07-15              0         Mon           BOS
# 9564   1979-05-13              0         Sun           MIL
# 177930 2001-04-12              0         Thu           ATL
# 166779 2011-06-18              0         Sat           PHI
# 27394  1967-04-29              0         Sat           PIT
# 100097 1921-10-01              2         Sat           WS1
# 93780  1955-07-17              0         Sun           WS1
# 119441 1926-06-04              0         Fri           SLN
#
#        visiting_team_league  visiting_team_game_number home_team  \
# 70528                    AL                          5       WS1
# 102422                   NL                        155       SDN
# 188422                   AL                         82       SLA
# 9564                     AL                         35       DET
# 177930                   NL                         10       NYN
# 166779                   NL                         72       SEA
# 27394                    NL                         16       SLN
# 100097                   AL                        153       BOS
# 93780                    AL                         91       KC1
# 119441                   NL                         51       PHI
#
#        home_team_league  home_team_game_number day_night  \
# 70528                AL                      5         D
# 102422               NL                    155         n
# 188422               AL                     85         D
# 9564                 AL                     32         D
# 177930               NL                      9         N
# 166779               AL                     73         N
# 27394                NL                     17         N
# 100097               AL                    153         D
# 93780                AL                     90         D
# 119441               NL                     48         D
#
#        postponement_indicator makeup_dates    yr
# 70528                    None         None  1929
# 102422                   None         None  2019
# 188422                   None         None  1907
# 9564                     None         None  1979
# 177930                   None         None  2001
# 166779                   None         None  2011
# 27394                    Rain     19670712  1967
# 100097                   None         None  1921
# 93780                    None         None  1955
# 119441                   Rain     19260605  1926

# %%
sched = sched.sort_values(['yr', 'home_team', 'home_team_game_number'])[['yr', 'home_team', 'home_team_game_number', 'visiting_team']].reset_index(drop=True)
sched
# Out:
#           yr home_team  home_team_game_number visiting_team
# 0       1877       BSN                     11           HAR
# 1       1877       BSN                     12           HAR
# 2       1877       BSN                     15           CHN
# 3       1877       BSN                     16           CHN
# 4       1877       BSN                     17           SL3
# ...      ...       ...                    ...           ...
# 220901  2019       WAS                    158           PHI
# 220902  2019       WAS                    159           PHI
# 220903  2019       WAS                    160           CLE
# 220904  2019       WAS                    161           CLE
# 220905  2019       WAS                    162           CLE
#
# [220906 rows x 4 columns]

# %%
# first look for consecutive games against same visitor
poss_series_id = (sched['visiting_team'] != sched['visiting_team'].shift()).cumsum()
poss_series_id
# Out:
# 0             1
# 1             1
# 2             2
# 3             2
# 4             3
#           ...
# 220901    72098
# 220902    72098
# 220903    72099
# 220904    72099
# 220905    72099
# Name: visiting_team, Length: 220906, dtype: int64

# %%
# 
offset = sched.reset_index().index - sched['home_team_game_number']
offset
# Out:
# 0            -11
# 1            -11
# 2            -13
# 3            -13
# 4            -13
#            ...
# 220901    220743
# 220902    220743
# 220903    220743
# 220904    220743
# 220905    220743
# Length: 220906, dtype: int64

# %%
sched['series_id'] = sched.groupby([poss_series_id, offset]).ngroup()
sched
# Out:
#           yr home_team  home_team_game_number visiting_team  series_id
# 0       1877       BSN                     11           HAR          0
# 1       1877       BSN                     12           HAR          0
# 2       1877       BSN                     15           CHN          1
# 3       1877       BSN                     16           CHN          1
# 4       1877       BSN                     17           SL3          2
# ...      ...       ...                    ...           ...        ...
# 220901  2019       WAS                    158           PHI      72984
# 220902  2019       WAS                    159           PHI      72984
# 220903  2019       WAS                    160           CLE      72985
# 220904  2019       WAS                    161           CLE      72985
# 220905  2019       WAS                    162           CLE      72985
#
# [220906 rows x 5 columns]

# %%
series_lengths = sched.groupby(['yr', 'series_id', 'home_team', 'visiting_team'])['home_team_game_number'].count().rename('length').reset_index().set_index('series_id')
series_lengths
# Out:
#              yr home_team visiting_team  length
# series_id
# 0          1877       BSN           HAR       2
# 1          1877       BSN           CHN       2
# 2          1877       BSN           SL3       2
# 3          1877       BSN           CN1       2
# 4          1877       BSN           LS1       2
# ...         ...       ...           ...     ...
# 72981      2019       WAS           MIA       3
# 72982      2019       WAS           NYN       3
# 72983      2019       WAS           ATL       3
# 72984      2019       WAS           PHI       4
# 72985      2019       WAS           CLE       3
#
# [72986 rows x 4 columns]

# %%
series_lengths.query('yr==2019')['length'].value_counts()
# Out:
# 3    518
# 4    175
# 2     88
# Name: length, dtype: int64

# %%
series_lengths.query('yr>=2000')['length'].value_counts()
# Out:
# 3    11741
# 4     2824
# 2     1037
# 1        7
# Name: length, dtype: int64

# %%
series_lengths.query('1980 <= yr <= 2000 and length==5')
# Out:
#              yr home_team visiting_team  length
# series_id
# 43576      1980       NYN           MON       5
# 43656      1980       PIT           CHN       5
# 43699      1980       SEA           MIN       5
# 43763      1980       SLN           PHI       5
# 43806      1980       TOR           CLE       5
# 43973      1981       CHN           SLN       5
# 44033      1981       CLE           MIL       5
# 44417      1981       SFN           ATL       5
# 44453      1981       SLN           PHI       5
# 44748      1982       DET           TOR       5
# 44854      1982       MIL           CLE       5
# 44961      1982       NYN           CHN       5
# 45041      1982       PIT           SLN       5
# 45120      1982       SFN           HOU       5
# 45191      1982       TOR           CLE       5
# 45322      1983       CHA           KCA       5
# 45352      1983       CHN           MON       5
# 45378      1983       CIN           ATL       5
# 45647      1983       NYN           PIT       5
# 45696      1983       PHI           NYN       5
# 45723      1983       PIT           SLN       5
# 45879      1983       TOR           BOS       5
# 46786      1985       CLE           NYA       5
# 47176      1985       SFN           SDN       5
# 47660      1986       MON           CHN       5
# 53819      1995       HOU           SDN       5
# 54010      1995       OAK           TOR       5
# 54238      1996       ATL           MON       5

# %%
series_lengths.query('yr >= 1970 and length==5')['yr'].value_counts()
# Out:
# 1971    8
# 1983    7
# 1977    7
# 1975    6
# 1982    6
# 1976    5
# 1980    5
# 1981    4
# 1973    4
# 1972    4
# 1979    3
# 1978    3
# 1974    3
# 1985    2
# 1995    2
# 1986    1
# 1996    1
# Name: yr, dtype: int64
