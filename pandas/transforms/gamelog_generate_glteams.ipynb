# %%
# Create a gamelog_team table (e.g., one row per team-game, two per game)

import pandas as pd
sys.path.append('../')
import retrosheetgl # for parsing linescores

# %%
data_dir = '/Users/vinay/dev/baseball_sql/data'

# %%
gl = pd.read_parquet(f'{data_dir}/mine/gamelog_enhanced.parquet')

# %%
# Select the per-team columns
vis_cols  = list(filter(lambda c: c.find('vis',  0)==0, gl.columns.values.tolist()))
home_cols = list(filter(lambda c: c.find('home', 0)==0, gl.columns.values.tolist()))

vis_col_mapper = dict([(c, c.replace('visitor_', '').replace('visiting_', '')) for c in vis_cols ])
hm_col_mapper  = dict([(c, c.replace('home_', ''))                             for c in home_cols])
    
vis_col_mapper
# Out:
# {'visiting_team': 'team',
#  'visiting_team_league': 'team_league',
#  'visiting_team_game_number': 'team_game_number',
#  'visitor_runs_scored': 'runs_scored',
#  'visitor_line_score': 'line_score',
#  'visitor_ab': 'ab',
#  'visitor_h': 'h',
#  'visitor_d': 'd',
#  'visitor_t': 't',
#  'visitor_hr': 'hr',
#  'visitor_rbi': 'rbi',
#  'visitor_sh': 'sh',
#  'visitor_sf': 'sf',
#  'visitor_hbp': 'hbp',
#  'visitor_bb': 'bb',
#  'visitor_ibb': 'ibb',
#  'visitor_k': 'k',
#  'visitor_sb': 'sb',
#  'visitor_cs': 'cs',
#  'visitor_gdp': 'gdp',
#  'visitor_ci': 'ci',
#  'visitor_lob': 'lob',
#  'visitor_pitchers': 'pitchers',
#  'visitor_er': 'er',
#  'visitor_ter': 'ter',
#  'visitor_wp': 'wp',
#  'visitor_balks': 'balks',
#  'visitor_po': 'po',
#  'visitor_a': 'a',
#  'visitor_e': 'e',
#  'visitor_passed': 'passed',
#  'visitor_db': 'db',
#  'visitor_tp': 'tp',
#  'visitor_manager_id': 'manager_id',
#  'visitor_manager_name': 'manager_name',
#  'visitor_starting_pitcher_id': 'starting_pitcher_id',
#  'visitor_starting_pitcher_name': 'starting_pitcher_name',
#  'visitor_batting_1_player_id': 'batting_1_player_id',
#  'visitor_batting_1_name': 'batting_1_name',
#  'visitor_batting_1_position': 'batting_1_position',
#  'visitor_batting_2_player_id': 'batting_2_player_id',
#  'visitor_batting_2_name': 'batting_2_name',
#  'visitor_batting_2_position': 'batting_2_position',
#  'visitor_batting_3_player_id': 'batting_3_player_id',
#  'visitor_batting_3_name': 'batting_3_name',
#  'visitor_batting_3_position': 'batting_3_position',
#  'visitor_batting_4_player_id': 'batting_4_player_id',
#  'visitor_batting_4_name': 'batting_4_name',
#  'visitor_batting_4_position': 'batting_4_position',
#  'visitor_batting_5_player_id': 'batting_5_player_id',
#  'visitor_batting_5_name': 'batting_5_name',
#  'visitor_batting_5_position': 'batting_5_position',
#  'visitor_batting_6_player_id': 'batting_6_player_id',
#  'visitor_batting_6_name': 'batting_6_name',
#  'visitor_batting_6_position': 'batting_6_position',
#  'visitor_batting_7_player_id': 'batting_7_player_id',
#  'visitor_batting_7_name': 'batting_7_name',
#  'visitor_batting_7_position': 'batting_7_position',
#  'visitor_batting_8_player_id': 'batting_8_player_id',
#  'visitor_batting_8_name': 'batting_8_name',
#  'visitor_batting_8_position': 'batting_8_position',
#  'visitor_batting_9_player_id': 'batting_9_player_id',
#  'visitor_batting_9_name': 'batting_9_name',
#  'visitor_batting_9_position': 'batting_9_position'}

# %%
neutral_cols = gl[['game_id', 'date', 'double_header', 'yr', 'game_type', 'park_id']]

gl_hometeam = pd.concat([neutral_cols, gl[home_cols].rename(columns= hm_col_mapper)], axis=1)
gl_visteam  = pd.concat([neutral_cols, gl[vis_cols].rename(columns=vis_col_mapper)], axis=1)

#gl_hometeam = gl[home_cols].rename(columns= hm_col_mapper)
#gl_visteam  = gl[vis_cols].rename(columns=vis_col_mapper)

gl_hometeam['HA'] = 'H'
gl_visteam ['HA'] = 'A'

gl_hometeam['opp'] = gl_visteam ['team']
gl_visteam ['opp'] = gl_hometeam['team']

gl_hometeam['runs_allowed'] = gl_visteam ['runs_scored']
gl_visteam ['runs_allowed'] = gl_hometeam['runs_scored']

gl_hometeam['W'] = gl_hometeam['runs_scored'] > gl_visteam ['runs_scored']
gl_hometeam['L'] = gl_hometeam['runs_scored'] < gl_visteam ['runs_scored']
gl_visteam['L'] = gl_hometeam['runs_scored'] > gl_visteam ['runs_scored']
gl_visteam['W'] = gl_hometeam['runs_scored'] < gl_visteam ['runs_scored']

gl_teams = pd.concat([gl_hometeam, gl_visteam], axis=0).sort_values('date')
gl_teams
# Out:
#              game_id       date double_header    yr game_type park_id team  \
# 2119    FW1187105040 1871-05-04             0  1871        RS   FOR01  FW1
# 2119    FW1187105040 1871-05-04             0  1871        RS   FOR01  CL1
# 2120    WS3187105050 1871-05-05             0  1871        RS   WAS01  BS1
# 2120    WS3187105050 1871-05-05             0  1871        RS   WAS01  WS3
# 2121    RC1187105060 1871-05-06             0  1871        RS   RCK01  RC1
# ...              ...        ...           ...   ...       ...     ...  ...
# 184592  PHI202211020 2022-11-02             0  2022        PS   PHI13  PHI
# 184593  PHI202211030 2022-11-03             0  2022        PS   PHI13  HOU
# 184593  PHI202211030 2022-11-03             0  2022        PS   PHI13  PHI
# 184594  HOU202211050 2022-11-05             0  2022        PS   HOU03  HOU
# 184594  HOU202211050 2022-11-05             0  2022        PS   HOU03  PHI
#
#        team_league  team_game_number  runs_scored  ...   batting_8_name  \
# 2119          None                 1            2  ...  James McDermott
# 2119          None                 1            0  ...     Jim Carleton
# 2120          None                 1           20  ...        Fred Cone
# 2120          None                 1           18  ...  Henry Burroughs
# 2121          None                 1            4  ...      George Bird
# ...            ...               ...          ...  ...              ...
# 184592          NL                 4            0  ...      Jean Segura
# 184593          AL                 5            3  ...   Chas McCormick
# 184593          NL                 5            2  ...      Jean Segura
# 184594          AL                 6            4  ...   Chas McCormick
# 184594          NL                 6            1  ...    Matt Vierling
#
#         batting_8_position  batting_9_player_id    batting_9_name  \
# 2119                   8.0             kellb105        Bill Kelly
# 2119                   3.0             bassj101         John Bass
# 2120                   7.0             spala101       Al Spalding
# 2120                   9.0             berth101   Henry Berthrong
# 2121                   7.0             stirg101        Gat Stires
# ...                    ...                  ...               ...
# 184592                 4.0             marsb002     Brandon Marsh
# 184593                 8.0             maldm001  Martin Maldonado
# 184593                 4.0             marsb002     Brandon Marsh
# 184594                 8.0             maldm001  Martin Maldonado
# 184594                 8.0             sosae001      Edmundo Sosa
#
#         batting_9_position  HA  opp  runs_allowed      W      L
# 2119                   9.0   H  CL1             0   True  False
# 2119                   6.0   A  FW1             2  False   True
# 2120                   1.0   A  WS3            18   True  False
# 2120                   8.0   H  BS1            20  False   True
# 2121                   9.0   H  CL1            12  False   True
# ...                    ...  ..  ...           ...    ...    ...
# 184592                 8.0   H  HOU             5  False   True
# 184593                 2.0   A  PHI             2   True  False
# 184593                 8.0   H  HOU             3  False   True
# 184594                 2.0   H  PHI             1   True  False
# 184594                 6.0   A  HOU             4  False   True
#
# [456386 rows x 75 columns]

# %%
# Parse linescores
def parse_linescore_str(obj):
    if obj:
        return retrosheetgl.parse_linescore_str(obj)
    else:
        return None

# %%
linescores = gl_teams.line_score.apply(parse_linescore_str)
gl_teams['linescore_parsed'] = linescores
gl_teams
# Out:
#              game_id       date double_header    yr game_type park_id team  \
# 2119    FW1187105040 1871-05-04             0  1871        RS   FOR01  FW1
# 2119    FW1187105040 1871-05-04             0  1871        RS   FOR01  CL1
# 2120    WS3187105050 1871-05-05             0  1871        RS   WAS01  BS1
# 2120    WS3187105050 1871-05-05             0  1871        RS   WAS01  WS3
# 2121    RC1187105060 1871-05-06             0  1871        RS   RCK01  RC1
# ...              ...        ...           ...   ...       ...     ...  ...
# 184592  PHI202211020 2022-11-02             0  2022        PS   PHI13  PHI
# 184593  PHI202211030 2022-11-03             0  2022        PS   PHI13  HOU
# 184593  PHI202211030 2022-11-03             0  2022        PS   PHI13  PHI
# 184594  HOU202211050 2022-11-05             0  2022        PS   HOU03  HOU
# 184594  HOU202211050 2022-11-05             0  2022        PS   HOU03  PHI
#
#        team_league  team_game_number  runs_scored  ... batting_8_position  \
# 2119          None                 1            2  ...                8.0
# 2119          None                 1            0  ...                3.0
# 2120          None                 1           20  ...                7.0
# 2120          None                 1           18  ...                9.0
# 2121          None                 1            4  ...                7.0
# ...            ...               ...          ...  ...                ...
# 184592          NL                 4            0  ...                4.0
# 184593          AL                 5            3  ...                8.0
# 184593          NL                 5            2  ...                4.0
# 184594          AL                 6            4  ...                8.0
# 184594          NL                 6            1  ...                8.0
#
#         batting_9_player_id    batting_9_name  batting_9_position  HA  opp  \
# 2119               kellb105        Bill Kelly                 9.0   H  CL1
# 2119               bassj101         John Bass                 6.0   A  FW1
# 2120               spala101       Al Spalding                 1.0   A  WS3
# 2120               berth101   Henry Berthrong                 8.0   H  BS1
# 2121               stirg101        Gat Stires                 9.0   H  CL1
# ...                     ...               ...                 ...  ..  ...
# 184592             marsb002     Brandon Marsh                 8.0   H  HOU
# 184593             maldm001  Martin Maldonado                 2.0   A  PHI
# 184593             marsb002     Brandon Marsh                 8.0   H  HOU
# 184594             maldm001  Martin Maldonado                 2.0   H  PHI
# 184594             sosae001      Edmundo Sosa                 6.0   A  HOU
#
#         runs_allowed      W      L                linescore_parsed
# 2119               0   True  False     [0, 1, 0, 0, 1, 0, 0, 0, 0]
# 2119               2  False   True     [0, 0, 0, 0, 0, 0, 0, 0, 0]
# 2120              18   True  False     [1, 0, 7, 0, 0, 0, 4, 3, 5]
# 2120              20  False   True     [6, 4, 0, 1, 1, 3, 0, 3, 0]
# 2121              12  False   True     [0, 1, 0, 0, 2, 0, 1, 0, 0]
# ...              ...    ...    ...                             ...
# 184592             5  False   True     [0, 0, 0, 0, 0, 0, 0, 0, 0]
# 184593             2   True  False     [1, 0, 0, 1, 0, 0, 0, 1, 0]
# 184593             3  False   True     [1, 0, 0, 0, 0, 0, 0, 1, 0]
# 184594             1   True  False  [0, 0, 0, 0, 0, 4, 0, 0, None]
# 184594             4  False   True     [0, 0, 0, 0, 0, 1, 0, 0, 0]
#
# [456386 rows x 76 columns]

# %%
gl_teams.to_parquet(f'{data_dir}/mine/gl_teams.parquet')

# %%
gl_teams.columns
# Out:
# Index(['game_id', 'date', 'double_header', 'yr', 'game_type', 'park_id',
#        'team', 'team_league', 'team_game_number', 'runs_scored', 'line_score',
#        'ab', 'h', 'd', 't', 'hr', 'rbi', 'sh', 'sf', 'hbp', 'bb', 'ibb', 'k',
#        'sb', 'cs', 'gdp', 'ci', 'lob', 'pitchers', 'er', 'ter', 'wp', 'balks',
#        'po', 'a', 'e', 'passed', 'db', 'tp', 'manager_id', 'manager_name',
#        'starting_pitcher_id', 'starting_pitcher_name', 'batting_1_player_id',
#        'batting_1_name', 'batting_1_position', 'batting_2_player_id',
#        'batting_2_name', 'batting_2_position', 'batting_3_player_id',
#        'batting_3_name', 'batting_3_position', 'batting_4_player_id',
#        'batting_4_name', 'batting_4_position', 'batting_5_player_id',
#        'batting_5_name', 'batting_5_position', 'batting_6_player_id',
#        'batting_6_name', 'batting_6_position', 'batting_7_player_id',
#        'batting_7_name', 'batting_7_position', 'batting_8_player_id',
#        'batting_8_name', 'batting_8_position', 'batting_9_player_id',
#        'batting_9_name', 'batting_9_position', 'HA', 'opp', 'runs_allowed',
#        'W', 'L', 'linescore_parsed'],
#       dtype='object')

# %%
def get_starters(i, tmgms):
    fields=[f'batting_{i}_player_id', 'game_id', 'date', 'yr', 'game_type', 'team', 'HA', f'batting_{i}_position']
    starters = tmgms[fields].dropna(axis=0, how='any')
    starters = starters.rename(columns={f'batting_{i}_player_id': 'player_id', f'batting_{i}_position': 'pos'})
    starters['batting_pos']=i
    return starters

gl_starters = pd.concat([get_starters(i+1, gl_teams) for i in range(9)])
gl_starters
# Out:
#        player_id       game_id       date    yr game_type team HA  pos  \
# 2119    selmf101  FW1187105040 1871-05-04  1871        RS  FW1  H  5.0
# 2119    whitd102  FW1187105040 1871-05-04  1871        RS  CL1  A  2.0
# 2120    wrigg101  WS3187105050 1871-05-05  1871        RS  BS1  A  6.0
# 2120    watef102  WS3187105050 1871-05-05  1871        RS  WS3  H  5.0
# 2121    mackd101  RC1187105060 1871-05-06  1871        RS  RC1  H  3.0
# ...          ...           ...        ...   ...       ...  ... ..  ...
# 184592  marsb002  PHI202211020 2022-11-02  2022        PS  PHI  H  8.0
# 184593  maldm001  PHI202211030 2022-11-03  2022        PS  HOU  A  2.0
# 184593  marsb002  PHI202211030 2022-11-03  2022        PS  PHI  H  8.0
# 184594  maldm001  HOU202211050 2022-11-05  2022        PS  HOU  H  2.0
# 184594  sosae001  HOU202211050 2022-11-05  2022        PS  PHI  A  6.0
#
#         batting_pos
# 2119              1
# 2119              1
# 2120              1
# 2120              1
# 2121              1
# ...             ...
# 184592            9
# 184593            9
# 184593            9
# 184594            9
# 184594            9
#
# [3742035 rows x 9 columns]

# %%
gl_starters.batting_pos.value_counts()
# Out:
# 1    415782
# 2    415782
# 3    415782
# 4    415782
# 5    415782
# 6    415782
# 7    415782
# 8    415782
# 9    415779
# Name: batting_pos, dtype: int64

# %%
gl_starters.to_parquet(f'{data_dir}/mine/gl_starters.parquet')

# %%
gl.head()
# Out:
#            date double_header day_of_week visiting_team visiting_team_league  \
# 2119 1871-05-04             0         Thu           CL1                 None
# 2120 1871-05-05             0         Fri           BS1                 None
# 2121 1871-05-06             0         Sat           CL1                 None
# 2122 1871-05-08             0         Mon           CL1                 None
# 2123 1871-05-09             0         Tue           BS1                 None
#
#       visiting_team_game_number home_team home_team_league  \
# 2119                          1       FW1             None
# 2120                          1       WS3             None
# 2121                          2       RC1             None
# 2122                          3       CH1             None
# 2123                          2       TRO             None
#
#       home_team_game_number  visitor_runs_scored  ...  home_batting_8_name  \
# 2119                      1                    0  ...      James McDermott
# 2120                      1                   20  ...      Henry Burroughs
# 2121                      1                   12  ...          George Bird
# 2122                      1                   12  ...           Ed Pinkham
# 2123                      1                    9  ...             Lip Pike
#
#       home_batting_8_position home_batting_9_player_id home_batting_9_name  \
# 2119                      8.0                 kellb105          Bill Kelly
# 2120                      9.0                 berth101     Henry Berthrong
# 2121                      7.0                 stirg101          Gat Stires
# 2122                      5.0                 zettg101     George Zettlein
# 2123                      3.0                 cravb101         Bill Craver
#
#      home_batting_9_position additional_info acquisition_info       game_id  \
# 2119                     9.0            None                D  FW1187105040
# 2120                     8.0            HTBF                D  WS3187105050
# 2121                     9.0            None                D  RC1187105060
# 2122                     1.0            None                D  CH1187105080
# 2123                     6.0            HTBF                D  TRO187105090
#
#         yr game_type
# 2119  1871        RS
# 2120  1871        RS
# 2121  1871        RS
# 2122  1871        RS
# 2123  1871        RS
#
# [5 rows x 164 columns]
