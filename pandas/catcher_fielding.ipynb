# %% [markdown]
# ## Evaluate catcher defense by looking at baserunner events
# SB, CS, WP, PB, PO, other outs/advancements
#
# Also look at pitchers, so that we can come up with adjustments for pitcher quality (e.g., knuckleballers are tough)

# %%
import pandas as pd
import boxball_loader as bbl 
import baseball_stats_utils as bsu

# %%
ev = bbl.load_event_data(1970, 2020, ['pos2_fld_id', 'inn_ct', 'pit_id', 'outs_ct'], pa_only=False)

# %%
# Add re24 to events

# TODO move this to boxball_loader
def add_re24_to_events(df_events: pd.DataFrame):
    event_res = pd.read_csv('~/temp/event_res.csv')
    if 'event_re' not in df_events.columns:
        df_merged = pd.merge(left=df_events, right=event_res, on='event_cd') 
        return df_merged
    else:
        return df_events

# %%
ev = add_re24_to_events(ev)

# %%
ev.columns
# Out:
# Index(['game_id', 'date', 'game_type', 'event_cd', 'pos2_fld_id', 'outs_ct',
#        'pit_id', 'bat_event_fl', 'tb_ct', 'inn_ct', 'ab_fl', 'h_fl', 'ob_fl',
#        'yr', 'event_re'],
#       dtype='object')

# %%
ev.sample(10)
# Out:
#               game_id       date game_type  event_cd pos2_fld_id  outs_ct  \
# 3401156  NYA201907200 2019-07-20        RS        20    woltt001        1
# 1206072  CIN201507180 2015-07-18        RS         3    penab002        1
# 2673035  SEA199308130 1993-08-13        RS        20    valld001        2
# 7193137  TOR201007260 2010-07-26        RS         2    wietm001        2
# 7130892  MIN200909200 2009-09-20        RS         2    mauej001        0
# 1484673  ATL197705170 1977-05-17        RS        14    footb101        0
# 8801976  SDN198707200 1987-07-20        RS        19    sundj001        0
# 8013637  TOR202008280 2020-08-28        RS         2    sevep001        1
# 6346888  SEA200106040 2001-06-04        RS         2    lampt001        1
# 6185163  OAK199907190 1999-07-19        RS         2    hernr002        2
#
#            pit_id  bat_event_fl  tb_ct  inn_ct  ab_fl  h_fl  ob_fl    yr  \
# 3401156  senza001          True      1       2   True     1      1  2019
# 1206072  diazj005          True      0       8   True     0      0  2015
# 2673035  hanse001          True      1       7   True     1      1  1993
# 7193137  albem001          True      0       7   True     0      0  2010
# 7130892  bakes002          True      0       4   True     0      0  2009
# 1484673  wartd101          True      0       5  False     0      1  1977
# 8801976  dipif001          True      0       7  False     0      0  1987
# 8013637  meanj001          True      0       4   True     0      0  2020
# 6346888  franr001          True      0       3   True     0      0  2001
# 6185163  joned001          True      0       8   True     0      0  1999
#
#          event_re
# 3401156  0.456976
# 1206072 -0.277322
# 2673035  0.456976
# 7193137 -0.275843
# 7130892 -0.275843
# 1484673  0.311613
# 8801976 -0.194241
# 8013637 -0.275843
# 6346888 -0.275843
# 6185163 -0.275843

# %%
ev['bat_event_fl'].value_counts()
# Out:
# True     8524001
# False     308449
# Name: bat_event_fl, dtype: int64

# %%
ev[~ev['bat_event_fl']]['event_cd'].value_counts()
# Out:
# 4     129713
# 9      64969
# 6      49191
# 8      26646
# 10     15223
# 11     10395
# 5       6492
# 12      2991
# 13      2829
# Name: event_cd, dtype: int64

# %%
# Ignore defensive interference, foul error. 
# Other advancement/out (12) seems to jump around a lot in frequency; need to understand this better, so leaving it out for now
# Eventually would probably be good to split these into different sets of categories, based on 
# how much the catcher influences each one
bsr_ev = ev[(~ev['bat_event_fl']) & (~ev['event_cd'].isin([5, 12, 13]))]
bsr_ev['event_cd'].value_counts()
# Out:
# 4     129713
# 9      64969
# 6      49191
# 8      26646
# 10     15223
# 11     10395
# Name: event_cd, dtype: int64

# %%
# Compute league totals for baselines

lg_outs = ev.groupby(['yr'])['outs_ct'].sum().apply(int)

# get counts by event type
evt_counts = pd.get_dummies(bsr_ev['event_cd'], prefix='ev')
evt_counts = pd.concat([bsr_ev[['yr', 'event_re']], evt_counts], axis=1)

lg_bsr_runs = evt_counts.groupby(['yr']).sum()
lg_totals = pd.concat([lg_outs, lg_bsr_runs], axis=1)
lg_totals

lg_rates = lg_totals.divide(lg_totals['outs_ct'], axis=0) * 3000 # per 1000 innings

lg_rates
# Out:
#       outs_ct  event_re       ev_4       ev_6       ev_8       ev_9     ev_10  \
# yr
# 1970   3000.0  6.182845  36.181724  16.390182   8.553129  24.247126  7.180650
# 1971   3000.0  5.079951  34.196388  16.602741   8.756379  21.961725  7.745249
# 1972   3000.0  4.042084  37.120527  18.719261   9.836622  22.280796  6.084290
# 1973   3000.0  4.601479  39.126804  18.569327  11.332459  23.678874  6.620542
# 1974   3000.0  4.245629  47.416474  21.931856  11.412504  20.959312  6.192524
# 1975   3000.0  4.933062  48.524196  21.616945  12.126096  22.449128  6.380070
# 1976   3000.0  4.490613  58.800861  25.453796  10.962872  20.390943  5.581099
# 1977   3000.0  2.758160  52.748090  26.165375  12.756074  20.703671  4.935494
# 1978   3000.0  3.985347  53.403817  23.290408  12.465808  18.919999  5.089590
# 1979   3000.0  4.475314  53.032023  22.659639  11.541506  20.321886  5.871994
# 1980   3000.0  4.915163  58.263053  23.312518  10.835396  18.095476  5.034628
# 1981   3000.0  3.942763  54.824704  23.690715  12.164752  18.941463  4.360425
# 1982   3000.0  4.826842  56.050568  22.992767  11.487267  19.327782  5.014283
# 1983   3000.0  5.274582  58.866692  23.058720  12.088860  18.802854  5.778438
# 1984   3000.0  4.927985  53.201970  23.736544   8.684547  19.485495  5.382230
# 1985   3000.0  5.707541  52.686272  21.327579   8.692410  19.567091  5.593217
# 1986   3000.0  5.689182  56.021203  25.417870   8.005628  21.997283  5.931443
# 1987   3000.0  7.978014  59.475061  22.494814   8.694868  22.206187  6.620366
# 1988   3000.0  9.840399  54.302103  20.340526   9.796959  21.032505  5.390148
# 1989   3000.0  6.658729  50.295678  19.587880  11.412546  21.416814  5.303908
# 1990   3000.0  6.893142  52.949221  20.184155  11.067554  22.463306  6.199289
# 1991   3000.0  5.431039  50.996494  25.398325   7.212543  24.253765  6.249659
# 1992   3000.0  4.445248  53.312885  26.346059   7.723065  22.676234  4.966132
# 1993   3000.0  5.298653  47.674321  23.181092   7.469089  22.844646  5.332660
# 1994   3000.0  7.203724  46.522944  17.916984  10.312272  25.239168  5.697648
# 1995   3000.0  7.905570  47.629780  16.039366  10.235895  23.796108  6.179100
# 1996   3000.0  7.523956  46.552211  15.955060   8.891622  23.433994  4.952717
# 1997   3000.0  6.277060  48.026114  17.894707  10.177719  22.196803  4.988422
# 1998   3000.0  6.441021  45.311073  18.468762   7.653580  22.929438  5.305856
# 1999   3000.0  6.969126  46.190945  16.242286   9.599129  23.196598  4.978478
# 2000   3000.0  6.247446  39.425096  14.041602   8.828367  21.566660  4.359879
# 2001   3000.0  5.999686  41.882395  15.295905   9.571767  21.430036  4.762230
# 2002   3000.0  6.466952  37.969865  13.830293   7.977795  21.332276  5.218081
# 2003   3000.0  7.108011  35.766688  11.880157   7.730780  22.450815  4.622691
# 2004   3000.0  6.985199  35.377876  11.306493   7.762433  21.013455  4.939730
# 2005   3000.0  6.553449  35.798688  11.588474   7.995888  20.601732  4.037685
# 2006   3000.0  7.244591  38.038831  11.929431   7.412615  21.655536  4.390912
# 2007   3000.0  8.314793  40.444777  10.983255   6.835073  21.636542  4.808120
# 2008   3000.0  8.123663  38.870243  11.031384   7.338475  22.851852  4.276831
# 2009   3000.0  7.674984  41.467749  12.034953   8.438663  22.792277  3.801342
# 2010   3000.0  7.922756  41.367049  12.460911   8.714701  23.953522  3.904948
# 2011   3000.0  7.510886  45.454064  13.717189   9.875106  22.306308  4.540644
# 2012   3000.0  8.481157  45.286688  11.875601   9.803349  22.157162  5.371916
# 2013   3000.0  8.414262  37.975895  11.148740   7.942879  25.200300  4.768918
# 2014   3000.0  8.174842  38.992976  11.765399   8.390080  24.832707  4.950469
# 2015   3000.0  7.639912  35.711420  12.214108   8.137389  25.744322  4.574272
# 2016   3000.0  8.349857  35.460766  11.425000   8.204208  26.631628  5.175701
# 2017   3000.0  8.991016  35.354532  10.158429   7.918775  26.411915  5.407164
# 2018   3000.0  8.872942  34.883721  10.342410   7.888279  26.660788  5.386340
# 2019   3000.0  8.977493  31.282024   8.287993   7.717500  26.210977  5.086895
# 2020   3000.0  9.627830  34.486334   9.154877   7.688319  27.064662  5.555144
#
#           ev_11
# yr
# 1970   2.565939
# 1971   1.961591
# 1972   1.950365
# 1973   1.888743
# 1974   3.711545
# 1975   4.022218
# 1976   3.547984
# 1977   4.282267
# 1978   5.034269
# 1979   3.055646
# 1980   4.669800
# 1981   5.026986
# 1982   4.704309
# 1983   4.879570
# 1984   5.163291
# 1985   4.162821
# 1986   5.258242
# 1987   6.421936
# 1988  16.826004
# 1989   7.443760
# 1990   5.251162
# 1991   4.378395
# 1992   3.998466
# 1993   5.013037
# 1994   4.096656
# 1995   3.737510
# 1996   3.274111
# 1997   3.147058
# 1998   3.208556
# 1999   2.753721
# 2000   2.498009
# 2001   2.381115
# 2002   2.537669
# 2003   2.492782
# 2004   2.462024
# 2005   2.559320
# 2006   2.282015
# 2007   2.184081
# 2008   2.414595
# 2009   2.176702
# 2010   2.889026
# 2011   2.683108
# 2012   2.630167
# 2013   2.041543
# 2014   2.057338
# 2015   2.263061
# 2016   2.371529
# 2017   2.479616
# 2018   2.406323
# 2019   2.424595
# 2020   2.799793

# %%
# single-se totals in raw runs
cat_ev_totals = bsr_ev.groupby(['pos2_fld_id', 'yr'])['event_re'].sum()
cat_ev_totals.sort_values()
# Out:
# pos2_fld_id  yr
# boonb001     1982   -10.508019
# fiskc001     1977    -9.201512
# cartg001     1979    -8.294928
# karkr001     1993    -7.352262
# dempr001     1977    -7.306428
#                        ...
# hatts001     2001    22.516942
# kendj001     2007    23.504638
# bardj001     2007    23.585429
# piazm001     1996    25.448091
# dietd101     1970    28.977813
# Name: event_re, Length: 4852, dtype: float64

# %%
# Let's compute vs league average

# Start by counting innings
cat_inn_totals = ev[['game_id', 'pos2_fld_id', 'inn_ct', 'yr']].drop_duplicates()[['pos2_fld_id', 'yr']].value_counts().rename('innings')
cat_inn_totals.sort_values()
# Out:
# pos2_fld_id  yr
# lecrm001     2005       1
# jonet002     1989       1
# sakal001     1983       1
# kearb001     1979       1
# cabrf001     1992       1
#                      ...
# sangm101     1974    1323
# kendj001     2008    1332
# simmt001     1973    1356
# cartg001     1982    1358
# fiskc001     1978    1364
# Name: innings, Length: 5140, dtype: int64

# %%
cat_totals = pd.concat([cat_inn_totals, cat_ev_totals], axis=1).fillna(0)
cat_totals
# Out:
#                   innings   event_re
# pos2_fld_id yr
# adamb105    1977        9   0.179519
# afent001    1987       52   1.653861
#             1990       33   0.029843
#             1991       28   0.440909
#             1992       93   1.270700
# ...                   ...        ...
# zunim001    2016      446   4.122584
#             2017      995  16.502276
#             2018      923   9.815331
#             2019      690   8.040438
#             2020      216   5.660714
#
# [5140 rows x 2 columns]

# %%
# Compute league averages
yr_totals = cat_totals.groupby('yr').sum()

re_rate = yr_totals['event_re'] / yr_totals['innings']
re_rate * 8.5 * 162 # full season equivalent
# Out:
# yr
# 1970    12.224998
# 1971     9.905074
# 1972     7.815137
# 1973     9.101294
# 1974     8.396596
# 1975     9.833118
# 1976     8.849940
# 1977     5.522422
# 1978     7.903213
# 1979     8.895504
# 1980     9.757630
# 1981     7.758738
# 1982     9.588078
# 1983    10.453410
# 1984     9.824646
# 1985    11.326727
# 1986    11.373819
# 1987    16.133993
# 1988    19.674542
# 1989    13.233400
# 1990    13.794973
# 1991    10.848940
# 1992     8.823304
# 1993    10.663716
# 1994    14.666297
# 1995    16.016264
# 1996    15.300300
# 1997    12.705751
# 1998    12.992032
# 1999    14.213004
# 2000    12.765520
# 2001    12.055058
# 2002    12.923462
# 2003    14.259218
# 2004    14.078696
# 2005    13.080232
# 2006    14.600492
# 2007    16.709955
# 2008    16.282624
# 2009    15.422036
# 2010    15.807767
# 2011    14.902978
# 2012    16.838005
# 2013    16.571451
# 2014    16.001877
# 2015    15.044494
# 2016    16.515680
# 2017    17.820097
# 2018    17.557442
# 2019    17.893886
# 2020    19.216461
# dtype: float64

# %%
# Now compare vs league average
cat_totals['baseline_re'] = cat_totals['innings'] * re_rate
cat_totals['re_diff'] = cat_totals['baseline_re'] - cat_totals['event_re']
cat_totals.sort_values('re_diff').tail(20)
# Out:
#                   innings   event_re  baseline_re    re_diff
# pos2_fld_id yr
# munst101    1975     1135  -3.893797     8.105003  11.998800
# schnb001    2004     1120  -0.649347    11.451082  12.100429
# realj001    2019     1144   2.618198    14.866089  12.247892
# wilsd001    1996     1133   0.166187    12.589136  12.422949
# moliy001    2010     1143   0.694835    13.121479  12.426644
# mathm001    2000     1035  -3.077890     9.594999  12.672888
# sundj001    1978     1300  -5.370902     7.461276  12.832177
# hanir001    2012      882  -2.563169    10.785127  13.348296
# santb001    1988     1173   3.243923    16.759795  13.515872
# johnc002    1997     1080  -3.647639     9.965295  13.612934
# fiskc001    1977     1320  -9.201512     5.293825  14.495338
# davij001    1986     1265  -4.321058    10.448715  14.769773
# parrl001    1990     1101  -3.790143    11.029968  14.820110
# karkr001    1993     1041  -7.352262     8.061677  15.413939
# rodri001    1999     1210  -2.979450    12.489277  15.468727
# pagnt001    1991     1159  -6.573707     9.131388  15.705095
# cartg001    1979     1218  -8.294928     7.868354  16.163283
#             1983     1266  -7.277766     9.610760  16.888526
# rodri001    1996     1229  -3.672485    13.655823  17.328309
# boonb001    1982     1254 -10.508019     8.731627  19.239646

# %%
# Career totals

careers = cat_totals.groupby('pos2_fld_id').sum()
careers.sort_values('re_diff', ascending=False)
# Out:
#              innings    event_re  baseline_re     re_diff
# pos2_fld_id
# rodri001       20427   80.659127   204.496775  123.837648
# moliy001       16726   72.213328   195.406241  123.192913
# sundj001       15955   28.713221   112.081339   83.368118
# dempr001       12367   14.160834    91.589004   77.428171
# boonb001       18521   67.962532   141.099137   73.136605
# ...              ...         ...          ...         ...
# hatts001        2906   68.834611    26.989770  -41.844840
# piazm001       13596  181.192843   132.492521  -48.700322
# barrm003        7343  124.249894    74.033076  -50.216818
# piera001       16402  230.370464   178.510659  -51.859805
# taube001        6597  116.225439    61.607230  -54.618209
#
# [940 rows x 4 columns]

# %%
# career rates
careers['re_diff_rate'] = careers['re_diff']/careers['innings'] * 1000 # represent as full-season eqv
careers[careers['innings']>=5000].sort_values(by='re_diff_rate')
# Out:
#              innings    event_re  baseline_re     re_diff  re_diff_rate
# pos2_fld_id
# taube001        6597  116.225439    61.607230  -54.618209     -8.279249
# barrm003        7343  124.249894    74.033076  -50.216818     -6.838733
# stanm002        5645   94.272414    57.261360  -37.011054     -6.556431
# fitzm001        5756   88.800884    52.352862  -36.448022     -6.332179
# flowt001        6229  108.692629    75.368177  -33.324453     -5.349888
# ...              ...         ...          ...         ...           ...
# pagnt001        6704   16.279843    61.492674   45.212831      6.744157
# poseb001        8431   40.921805   101.494046   60.572242      7.184467
# moliy001       16726   72.213328   195.406241  123.192913      7.365354
# karkr001        6999    9.740195    67.041010   57.300815      8.187000
# obric001        5995    7.251946    58.785627   51.533680      8.596110
#
# [144 rows x 5 columns]
