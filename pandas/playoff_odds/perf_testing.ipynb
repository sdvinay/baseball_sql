# %%
import season_simulator as sim

# %%
(played, remain) = sim.get_games()
rand0 = sim.get_randoms(0)
cur_standings = sim.compute_standings(played)
rem_standings = sim.sim_rem_games(remain, rand0)
full_standings = cur_standings+rem_standings

# %%
# %%prun -s cumulative # This runs the code profiler, which creates data I can use to find opportunities for me to speed up the code

[sim.add_playoff_seeds(full_standings, rand0) for _ in range(10)]
None # This is to suppress printing the output, which is 1000 lines of the same list of teams
# Out:
#          158751 function calls (156980 primitive calls) in 0.072 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.072    0.072 {built-in method builtins.exec}
#         1    0.000    0.000    0.072    0.072 <string>:1(<module>)
#         1    0.000    0.000    0.072    0.072 <string>:3(<listcomp>)
#        10    0.000    0.000    0.072    0.007 season_simulator.py:25(add_playoff_seeds)
#        40    0.000    0.000    0.025    0.001 _decorators.py:302(wrapper)
#        30    0.000    0.000    0.023    0.001 frame.py:6275(sort_values)
#        30    0.001    0.000    0.016    0.001 sorting.py:285(lexsort_indexer)
#        10    0.000    0.000    0.016    0.002 season_simulator.py:56(get_league_structure)
#       170    0.001    0.000    0.012    0.000 frame.py:3463(__getitem__)
#   366/306    0.001    0.000    0.012    0.000 series.py:323(__init__)
# ...

# %%
# %%prun -s cumulative # This runs the code profiler, which creates data I can use to find opportunities for me to speed up the code

sim_results = sim.sim_n_seasons(cur_standings, remain, 1*1000)
sim.summarize_sim_results(sim_results)
# Out:
#          26136973 function calls (25810593 primitive calls) in 9.117 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    9.118    9.118 {built-in method builtins.exec}
#         1    0.003    0.003    9.118    9.118 <string>:1(<module>)
#         1    0.006    0.006    9.104    9.104 season_simulator.py:135(sim_n_seasons)
#         1    0.001    0.001    9.001    9.001 season_simulator.py:136(<listcomp>)
#      1000    0.015    0.000    9.000    0.009 season_simulator.py:128(sim_1_season)
#      1000    0.016    0.000    7.732    0.008 season_simulator.py:122(finish_one_season)
#      1000    0.022    0.000    5.808    0.006 season_simulator.py:25(add_playoff_seeds)
#     11013    0.012    0.000    3.508    0.000 _decorators.py:302(wrapper)
#      3000    0.019    0.000    1.708    0.001 frame.py:6275(sort_values)
# ...
