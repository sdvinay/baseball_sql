# %%
import pandas as pd
import boxball_loader as bbl

# %%
df1 = bbl.load_gamelogs(bbl.GameType.RS, bbl.Eras.since(2015))
df1
# Out:
#              date double_header day_of_week visiting_team  \
# 204326 2015-04-05             0         Sun           SLN
# 204327 2015-04-06             0         Mon           MIN
# 204328 2015-04-06             0         Mon           CLE
# 204340 2015-04-06             0         Mon           NYN
# 204339 2015-04-06             0         Mon           BOS
# ...           ...           ...         ...           ...
# 161558 2020-09-27             0         Sun           MIA
# 161560 2020-09-27             0         Sun           PHI
# 161562 2020-09-27             0         Sun           BAL
# 161561 2020-09-27             0         Sun           HOU
# 161556 2020-09-27             0         Sun           DET
#
#        visiting_team_league  visiting_team_game_number home_team  \
# 204326                   NL                          1       CHN
# 204327                   AL                          1       DET
# 204328                   AL                          1       HOU
# ...

# %%
df2 = bbl.load_gamelogs(bbl.GameType.ALL, bbl.Eras.since(2015))
df2
# Out:
#              date double_header day_of_week visiting_team  \
# 204326 2015-04-05             0         Sun           SLN
# 204327 2015-04-06             0         Mon           MIN
# 204328 2015-04-06             0         Mon           CLE
# 204340 2015-04-06             0         Mon           NYN
# 204339 2015-04-06             0         Mon           BOS
# ...           ...           ...         ...           ...
# 155696 2020-10-21             0         Wed           TBA
# 155697 2020-10-23             0         Fri           LAN
# 155698 2020-10-24             0         Sat           LAN
# 155699 2020-10-25             0         Sun           LAN
# 155700 2020-10-27             0         Tue           TBA
#
#        visiting_team_league  visiting_team_game_number home_team  \
# 204326                   NL                          1       CHN
# 204327                   AL                          1       DET
# 204328                   AL                          1       HOU
# ...

# %%
bbl.get_cols_from_roles(bbl.PlayerRole.PIT)
# Out:
# ['game_id',
#  'game_dt',
#  'game_ct',
#  'appearance_dt',
#  'team_id',
#  'player_id',
#  'slot_ct',
#  'seq_ct',
#  'home_fl',
#  'opponent_id',
#  'park_id',
#  'yr',
#  'game_type',
#  'team_game_number',
#  ['p_g',
#   'p_gs',
#   'p_cg',
#   'p_sho',
#   'p_gf',
#   'p_w',
#   'p_l',
#   'p_sv',
#   'p_out',
#   'p_tbf',
#   'p_ab',
#   'p_r',
#   'p_er',
#   'p_h',
#   'p_tb',
#   'p_2b',
#   'p_3b',
#   'p_hr',
#   'p_hr4',
#   'p_bb',
#   'p_ibb',
#   'p_so',
#   'p_gdp',
#   'p_hp',
#   'p_sh',
#   'p_sf',
#   'p_xi',
#   'p_wp',
#   'p_bk',
#   'p_ir',
#   'p_irs',
#   'p_go',
#   'p_ao',
#   'p_pitch',
#   'p_strike']]

# %%
bbl.get_cols_from_roles(bbl.PlayerRole.BAT | bbl.PlayerRole.PIT)
# Out:
# ['game_id',
#  'game_dt',
#  'game_ct',
#  'appearance_dt',
#  'team_id',
#  'player_id',
#  'slot_ct',
#  'seq_ct',
#  'home_fl',
#  'opponent_id',
#  'park_id',
#  'yr',
#  'game_type',
#  'team_game_number',
#  ['b_g',
#   'b_pa',
#   'b_ab',
#   'b_r',
#   'b_h',
#   'b_tb',
#   'b_2b',
#   'b_3b',
#   'b_hr',
#   'b_hr4',
#   'b_rbi',
#   'b_gw',
#   'b_bb',
#   'b_ibb',
#   'b_so',
#   'b_gdp',
#   'b_hp',
#   'b_sh',
#   'b_sf',
#   'b_sb',
#   'b_cs',
#   'b_xi',
#   'b_g_dh',
#   'b_g_ph',
#   'b_g_pr'],
#  ['p_g',
#   'p_gs',
#   'p_cg',
#   'p_sho',
#   'p_gf',
#   'p_w',
#   'p_l',
#   'p_sv',
#   'p_out',
#   'p_tbf',
#   'p_ab',
#   'p_r',
#   'p_er',
#   'p_h',
#   'p_tb',
#   'p_2b',
#   'p_3b',
#   'p_hr',
#   'p_hr4',
#   'p_bb',
#   'p_ibb',
#   'p_so',
#   'p_gdp',
#   'p_hp',
#   'p_sh',
#   'p_sf',
#   'p_xi',
#   'p_wp',
#   'p_bk',
#   'p_ir',
#   'p_irs',
#   'p_go',
#   'p_ao',
#   'p_pitch',
#   'p_strike']]

# %%
inputs = [bbl.PlayerRole.PIT, bbl.PlayerRole.BAT]
[bbl.get_cols_from_roles(role) for role in inputs]
# Out:
# [['game_id',
#   'game_dt',
#   'game_ct',
#   'appearance_dt',
#   'team_id',
#   'player_id',
#   'slot_ct',
#   'seq_ct',
#   'home_fl',
#   'opponent_id',
#   'park_id',
#   'yr',
#   'game_type',
#   'team_game_number',
#   ['p_g',
#    'p_gs',
#    'p_cg',
#    'p_sho',
#    'p_gf',
#    'p_w',
#    'p_l',
#    'p_sv',
#    'p_out',
#    'p_tbf',
#    'p_ab',
#    'p_r',
#    'p_er',
#    'p_h',
#    'p_tb',
#    'p_2b',
#    'p_3b',
#    'p_hr',
#    'p_hr4',
#    'p_bb',
#    'p_ibb',
#    'p_so',
#    'p_gdp',
#    'p_hp',
#    'p_sh',
#    'p_sf',
#    'p_xi',
#    'p_wp',
#    'p_bk',
#    'p_ir',
#    'p_irs',
#    'p_go',
#    'p_ao',
#    'p_pitch',
#    'p_strike']],
#  ['game_id',
#   'game_dt',
#   'game_ct',
#   'appearance_dt',
#   'team_id',
#   'player_id',
#   'slot_ct',
#   'seq_ct',
#   'home_fl',
#   'opponent_id',
#   'park_id',
#   'yr',
#   'game_type',
#   'team_game_number',
#   ['b_g',
#    'b_pa',
#    'b_ab',
#    'b_r',
#    'b_h',
#    'b_tb',
# ...

# %%
df1 = bbl.load_dailies(bbl.GameType.RS)
df1
# Out:
#               game_id    game_dt  game_ct appearance_dt team_id player_id  \
# 1934     ANA199704020 1997-04-02        0    1997-04-02     ANA  alicl001
# 1935     ANA199704020 1997-04-02        0    1997-04-02     ANA  andeg001
# 1936     ANA199704020 1997-04-02        0    1997-04-02     ANA  disag001
# 1937     ANA199704020 1997-04-02        0    1997-04-02     ANA  edmoj001
# 1938     ANA199704020 1997-04-02        0    1997-04-02     ANA  erstd001
# ...               ...        ...      ...           ...     ...       ...
# 5198794  WS4187205170 1872-05-17        0    1872-05-17     WS4  hollh101
# 5198795  WS4187205170 1872-05-17        0    1872-05-17     WS4  lennb101
# 5198796  WS4187205170 1872-05-17        0    1872-05-17     WS4  mince101
# 5198797  WS4187205170 1872-05-17        0    1872-05-17     WS4  steab101
# 5198798  WS4187205170 1872-05-17        0    1872-05-17     WS4  whitw102
#
#          slot_ct  seq_ct  home_fl opponent_id  ... f_rf_out  f_rf_tc  f_rf_po  \
# ...

# %%
df2 = bbl.load_dailies(bbl.GameType.RS|bbl.GameType.PS)
df2
# Out:
#               game_id    game_dt  game_ct appearance_dt team_id player_id  \
# 1934     ANA199704020 1997-04-02        0    1997-04-02     ANA  alicl001
# 1935     ANA199704020 1997-04-02        0    1997-04-02     ANA  andeg001
# 1936     ANA199704020 1997-04-02        0    1997-04-02     ANA  disag001
# 1937     ANA199704020 1997-04-02        0    1997-04-02     ANA  edmoj001
# 1938     ANA199704020 1997-04-02        0    1997-04-02     ANA  erstd001
# ...               ...        ...      ...           ...     ...       ...
# 5198794  WS4187205170 1872-05-17        0    1872-05-17     WS4  hollh101
# 5198795  WS4187205170 1872-05-17        0    1872-05-17     WS4  lennb101
# 5198796  WS4187205170 1872-05-17        0    1872-05-17     WS4  mince101
# 5198797  WS4187205170 1872-05-17        0    1872-05-17     WS4  steab101
# 5198798  WS4187205170 1872-05-17        0    1872-05-17     WS4  whitw102
#
#          slot_ct  seq_ct  home_fl opponent_id  ... f_rf_out  f_rf_tc  f_rf_po  \
# ...

# %%
df3 = bbl.load_dailies(bbl.GameType.ALL)
df3
# Out:
#               game_id    game_dt  game_ct appearance_dt team_id player_id  \
# 0        ALS193307060 1933-07-06        0    1933-07-06     ALS  avere101
# 1        ALS193307060 1933-07-06        0    1933-07-06     ALS  chapb102
# 2        ALS193307060 1933-07-06        0    1933-07-06     ALS  cronj101
# 3        ALS193307060 1933-07-06        0    1933-07-06     ALS  crowg102
# 4        ALS193307060 1933-07-06        0    1933-07-06     ALS  dykej101
# ...               ...        ...      ...           ...     ...       ...
# 5198794  WS4187205170 1872-05-17        0    1872-05-17     WS4  hollh101
# 5198795  WS4187205170 1872-05-17        0    1872-05-17     WS4  lennb101
# 5198796  WS4187205170 1872-05-17        0    1872-05-17     WS4  mince101
# 5198797  WS4187205170 1872-05-17        0    1872-05-17     WS4  steab101
# 5198798  WS4187205170 1872-05-17        0    1872-05-17     WS4  whitw102
#
#          slot_ct  seq_ct  home_fl opponent_id  ... f_rf_out  f_rf_tc  f_rf_po  \
# ...

# %%
ev1 = bbl.load_event_data(bbl.Eras.since(1987), ['pitch_seq_tx'], pa_only=False, game_types=bbl.GameType.PS|bbl.GameType.RS)
ev2 = bbl.load_event_data(bbl.Eras.since(1987), ['pitch_seq_tx'], pa_only=False)
ev1.shape, ev2.shape

# expect ((6228945, 11), (6149539, 11))
# Out:
# ((6228945, 11), (6149539, 11))
